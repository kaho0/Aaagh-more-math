# %% [markdown]
# <a href="https://colab.research.google.com/github/kaho0/Aaagh-more-math/blob/main/Module6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use("default")
sns.set(font_scale=1.25)
from google.colab import files

# %%
from google.colab import drive
df=pd.read_csv('/content/drive/MyDrive/Datasets/heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
print("shape: ",df.shape)
# Out:
# shape:  (918, 12)

# %%
print("Info: ",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# Info:  None

# %%
df.describe().T
# Out:
#               count        mean         std   min     25%    50%    75%    max
# Age           918.0   53.510893    9.432617  28.0   47.00   54.0   60.0   77.0
# RestingBP     918.0  132.396514   18.514154   0.0  120.00  130.0  140.0  200.0
# Cholesterol   918.0  198.799564  109.384145   0.0  173.25  223.0  267.0  603.0
# FastingBS     918.0    0.233115    0.423046   0.0    0.00    0.0    0.0    1.0
# MaxHR         918.0  136.809368   25.460334  60.0  120.00  138.0  156.0  202.0
# Oldpeak       918.0    0.887364    1.066570  -2.6    0.00    0.6    1.5    6.2
# HeartDisease  918.0    0.553377    0.497414   0.0    0.00    1.0    1.0    1.0

# %%
target_col = "HeartDisease"

numeric_cols = ["Age", "RestingBP", "Cholesterol", "FastingBS",
                "MaxHR", "Oldpeak"]

categorical_cols = ["Sex", "ChestPainType", "RestingECG",
                    "ExerciseAngina", "ST_Slope"]

print("Target:", target_col)
print("Numeric columns:", numeric_cols)
print("Categorical columns:", categorical_cols)
# Out:
# Target: HeartDisease
# Numeric columns: ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak']
# Categorical columns: ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df[numeric_cols].agg(['min','max','mean','median']).T
# Out:
#               min    max        mean  median
# Age          28.0   77.0   53.510893    54.0
# RestingBP     0.0  200.0  132.396514   130.0
# Cholesterol   0.0  603.0  198.799564   223.0
# FastingBS     0.0    1.0    0.233115     0.0
# MaxHR        60.0  202.0  136.809368   138.0
# Oldpeak      -2.6    6.2    0.887364     0.6

# %%
for c in categorical_cols:
  print(c,df[c].unique())
# Out:
# Sex ['M' 'F']
# ChestPainType ['ATA' 'NAP' 'ASY' 'TA']
# RestingECG ['Normal' 'ST' 'LVH']
# ExerciseAngina ['N' 'Y']
# ST_Slope ['Up' 'Flat' 'Down']

# %%
df['Age'].hist(bins=20,figsize=(8,4))
plt.title("Histogram of numerical Feature age ",fontsize=14)
plt.tight_layout()
plt.show()

# %%
df['RestingBP'].hist(bins=20,figsize=(8,4))
plt.title("Histogram of numerical Resting BP ",fontsize=14)
plt.tight_layout()
plt.show()

# %%
df['Cholesterol'].hist(bins=20,figsize=(8,4))
plt.title("Histogram of numerical Feature cholesterol ",fontsize=14)
plt.tight_layout()
plt.show()

# %%
df[numeric_cols].hist(bins=20,figsize=(8,4))
plt.title("Histogram of numerical Featured ",fontsize=14)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
df[numeric_cols].boxplot()
plt.title("Boxplot of numerical Features ",fontsize=14)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
df.boxplot(column=numeric_cols[0])
plt.title("Boxplot of numerical Features ",fontsize=14)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df[target_col])
plt.title("Heart Disease class distribution ")
plt.xlabel("Heart Disease(0=No,1=Yes)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
for c in categorical_cols:
  plt.figure(figsize=(15,10))
  df[c].value_counts().plot(kind='bar')
  plt.title(f"Distribution of {c} ")
  plt.ylabel("Count")
  plt.tight_layout()
  plt.show()

# %%
plt.figure(figsize=(15,8))
for i,col in enumerate(numeric_cols,1):
  plt.subplot(2,3,i)
  sns.boxplot(x=df[target_col],y=df[col])
  plt.title(col)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df[["Age","Cholesterol","Oldpeak","HeartDisease"]],hue="HeartDisease",diag_kind="hist")
